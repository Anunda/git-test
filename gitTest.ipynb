# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a = np.random.random(30)*100
b = np.random.random(30)*100
d = np.random.random(30)*100
c = np.random.choice(['r','b'], 30)
# = np.random.randint(10,100.5)

# %%
a = np.sort(a)
b = np.sort(b)
d = np.sort(d)

# %%
plt.scatter(a,b**2,color=c)
plt.show()

# %%
sns.regplot(x=a,y=b**2)

# %%
from scipy.stats import linregress

# %%
res = linregress(a,b)
res
# Out:
# LinregressResult(slope=1.0273117105374403, intercept=10.46695764122775, rvalue=0.9632964972948236, pvalue=1.5751226815730903e-17, stderr=0.05410157941229294)

# %%
import statsmodels.formula.api as smf

# %%
results = smf.ols('a~b',data=data).fit()
results.params
# Out:
# Intercept   -6.08387
# b            0.90327
# dtype: float64
